# %% [markdown]
# # transformation_api module
#
# With `transformation_api` module is is possible to access the transformation application programming interface (API), which is available under https://ws.geonorge.no/transformering/v1.
#
# ## transformation API wrapper
#
# **transformation_api.py** is a Python wrapper around the transformation API.

# %%
# Import transformation API wrapper
from midgard.api import transformation_api

# Get instance of TransformationApi class with transformation API methods
api = transformation_api.TransformationApi()

# Get overview available transformation API functions
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_error_message',
#  '_exists_epsg',
#  '_get_available_epsg',
#  '_get_url',
#  'epsg',
#  'get_name',
#  'projections',
#  'proxy',
#  'transform',
#  'url']

# %%
# Get available EPSG codes
api.epsg
# Out:
# [4258,
#  4937,
#  5942,
#  6144,
#  4936,
#  25831,
#  25832,
#  25833,
#  25834,
#  25835,
#  25836,
#  6171,
#  6172,
#  6173,
#  6174,
#  6175,
#  6176,
#  5971,
#  5972,
#  5973,
#  5974,
#  5975,
#  5976,
#  5105,
#  5106,
#  5107,
#  5108,
#  5109,
#  5110,
#  5111,
#  5112,
#  5113,
#  5114,
#  5115,
#  5116,
#  5117,
#  5118,
#  5119,
#  5120,
#  5121,
#  5122,
#  5123,
#  5124,
#  5125,
#  5126,
#  5127,
#  5128,
#  5129,
#  5130,
#  6145,
#  6146,
#  6147,
#  6148,
#  6149,
#  6150,
#  6151,
#  6152,
#  6153,
#  6154,
#  6155,
#  6156,
#  6157,
#  6158,
#  6159,
#  6160,
#  6161,
#  6162,
#  6163,
#  6164,
#  6165,
#  6166,
#  6167,
#  6168,
#  6169,
#  6170,
#  5945,
#  5946,
#  5947,
#  5948,
#  5949,
#  5950,
#  5951,
#  5952,
#  5953,
#  5954,
#  5955,
#  5956,
#  5957,
#  5958,
#  5959,
#  5960,
#  5961,
#  5962,
#  5963,
#  5964,
#  5965,
#  5966,
#  5967,
#  5968,
#  5969,
#  5970,
#  5941,
#  5776,
#  9672,
#  9883,
#  20000,
#  20001,
#  4273,
#  27391,
#  27392,
#  27393,
#  27394,
#  27395,
#  27396,
#  27397,
#  27398,
#  9000,
#  7912,
#  7789,
#  9990,
#  9989,
#  9988,
#  4230,
#  23031,
#  23032,
#  23033,
#  23034,
#  23035,
#  23036,
#  4326]

# %%
# Get projection name
api.get_name(4936)
# Out:
# 'ETRS89 Geosentrisk'

# %%
# Get available projections
api.projections
# Out:
# OrderedDict([(4258, {'name': 'ETRS89 Geografisk 2D'}),
#              (4937, {'name': 'ETRS89 Geografisk 3D'}),
#              (5942, {'name': 'ETRS89 Geografisk NN2000'}),
#              (6144, {'name': 'ETRS89 Geografisk NN54'}),
#              (4936, {'name': 'ETRS89 Geosentrisk'}),
#              (25831, {'name': 'ETRS89 UTM 31 2D'}),
#              (25832, {'name': 'ETRS89 UTM 32 2D'}),
#              (25833, {'name': 'ETRS89 UTM 33 2D'}),
#              (25834, {'name': 'ETRS89 UTM 34 2D'}),
#              (25835, {'name': 'ETRS89 UTM 35 2D'}),
#              (25836, {'name': 'ETRS89 UTM 36 2D'}),
#              (6171, {'name': 'ETRS89 UTM 31 NN54'}),
#              (6172, {'name': 'ETRS89 UTM 32 NN54'}),
#              (6173, {'name': 'ETRS89 UTM 33 NN54'}),
#              (6174, {'name': 'ETRS89 UTM 34 NN54'}),
#              (6175, {'name': 'ETRS89 UTM 35 NN54'}),
#              (6176, {'name': 'ETRS89 UTM 36 NN54'}),
#              (5971, {'name': 'ETRS89 UTM 31 NN2000'}),
#              (5972, {'name': 'ETRS89 UTM 32 NN2000'}),
#              (5973, {'name': 'ETRS89 UTM 33 NN2000'}),
#              (5974, {'name': 'ETRS89 UTM 34 NN2000'}),
#              (5975, {'name': 'ETRS89 UTM 35 NN2000'}),
#              (5976, {'name': 'ETRS89 UTM 36 NN2000'}),
#              (5105, {'name': 'ETRS89 NTM 5 2D'}),
#              (5106, {'name': 'ETRS89 NTM 6 2D'}),
#              (5107, {'name': 'ETRS89 NTM 7 2D'}),
#              (5108, {'name': 'ETRS89 NTM 8 2D'}),
#              (5109, {'name': 'ETRS89 NTM 9 2D'}),
#              (5110, {'name': 'ETRS89 NTM 10 2D'}),
#              (5111, {'name': 'ETRS89 NTM 11 2D'}),
#              (5112, {'name': 'ETRS89 NTM 12 2D'}),
#              (5113, {'name': 'ETRS89 NTM 13 2D'}),
#              (5114, {'name': 'ETRS89 NTM 14 2D'}),
#              (5115, {'name': 'ETRS89 NTM 15 2D'}),
#              (5116, {'name': 'ETRS89 NTM 16 2D'}),
#              (5117, {'name': 'ETRS89 NTM 17 2D'}),
#              (5118, {'name': 'ETRS89 NTM 18 2D'}),
#              (5119, {'name': 'ETRS89 NTM 19 2D'}),
#              (5120, {'name': 'ETRS89 NTM 20 2D'}),
#              (5121, {'name': 'ETRS89 NTM 21 2D'}),
#              (5122, {'name': 'ETRS89 NTM 22 2D'}),
#              (5123, {'name': 'ETRS89 NTM 23 2D'}),
#              (5124, {'name': 'ETRS89 NTM 24 2D'}),
#              (5125, {'name': 'ETRS89 NTM 25 2D'}),
#              (5126, {'name': 'ETRS89 NTM 26 2D'}),
#              (5127, {'name': 'ETRS89 NTM 27 2D'}),
#              (5128, {'name': 'ETRS89 NTM 28 2D'}),
#              (5129, {'name': 'ETRS89 NTM 29 2D'}),
#              (5130, {'name': 'ETRS89 NTM 30 2D'}),
#              (6145, {'name': 'ETRS89 NTM 5 NN54'}),
#              (6146, {'name': 'ETRS89 NTM 6 NN54'}),
#              (6147, {'name': 'ETRS89 NTM 7 NN54'}),
#              (6148, {'name': 'ETRS89 NTM 8 NN54'}),
#              (6149, {'name': 'ETRS89 NTM 9 NN54'}),
#              (6150, {'name': 'ETRS89 NTM 10 NN54'}),
#              (6151, {'name': 'ETRS89 NTM 11 NN54'}),
#              (6152, {'name': 'ETRS89 NTM 12 NN54'}),
#              (6153, {'name': 'ETRS89 NTM 13 NN54'}),
#              (6154, {'name': 'ETRS89 NTM 14 NN54'}),
#              (6155, {'name': 'ETRS89 NTM 15 NN54'}),
#              (6156, {'name': 'ETRS89 NTM 16 NN54'}),
#              (6157, {'name': 'ETRS89 NTM 17 NN54'}),
#              (6158, {'name': 'ETRS89 NTM 18 NN54'}),
#              (6159, {'name': 'ETRS89 NTM 19 NN54'}),
#              (6160, {'name': 'ETRS89 NTM 20 NN54'}),
#              (6161, {'name': 'ETRS89 NTM 21 NN54'}),
#              (6162, {'name': 'ETRS89 NTM 22 NN54'}),
#              (6163, {'name': 'ETRS89 NTM 23 NN54'}),
#              (6164, {'name': 'ETRS89 NTM 24 NN54'}),
#              (6165, {'name': 'ETRS89 NTM 25 NN54'}),
#              (6166, {'name': 'ETRS89 NTM 26 NN54'}),
#              (6167, {'name': 'ETRS89 NTM 27 NN54'}),
#              (6168, {'name': 'ETRS89 NTM 28 NN54'}),
#              (6169, {'name': 'ETRS89 NTM 29 NN54'}),
#              (6170, {'name': 'ETRS89 NTM 30 NN54'}),
#              (5945, {'name': 'ETRS89 NTM 5 NN2000'}),
#              (5946, {'name': 'ETRS89 NTM 6 NN2000'}),
#              (5947, {'name': 'ETRS89 NTM 7 NN2000'}),
#              (5948, {'name': 'ETRS89 NTM 8 NN2000'}),
#              (5949, {'name': 'ETRS89 NTM 9 NN2000'}),
#              (5950, {'name': 'ETRS89 NTM 10 NN2000'}),
#              (5951, {'name': 'ETRS89 NTM 11 NN2000'}),
#              (5952, {'name': 'ETRS89 NTM 12 NN2000'}),
#              (5953, {'name': 'ETRS89 NTM 13 NN2000'}),
#              (5954, {'name': 'ETRS89 NTM 14 NN2000'}),
#              (5955, {'name': 'ETRS89 NTM 15 NN2000'}),
#              (5956, {'name': 'ETRS89 NTM 16 NN2000'}),
#              (5957, {'name': 'ETRS89 NTM 17 NN2000'}),
#              (5958, {'name': 'ETRS89 NTM 18 NN2000'}),
#              (5959, {'name': 'ETRS89 NTM 19 NN2000'}),
#              (5960, {'name': 'ETRS89 NTM 20 NN2000'}),
#              (5961, {'name': 'ETRS89 NTM 21 NN2000'}),
#              (5962, {'name': 'ETRS89 NTM 22 NN2000'}),
#              (5963, {'name': 'ETRS89 NTM 23 NN2000'}),
#              (5964, {'name': 'ETRS89 NTM 24 NN2000'}),
#              (5965, {'name': 'ETRS89 NTM 25 NN2000'}),
#              (5966, {'name': 'ETRS89 NTM 26 NN2000'}),
#              (5967, {'name': 'ETRS89 NTM 27 NN2000'}),
#              (5968, {'name': 'ETRS89 NTM 28 NN2000'}),
#              (5969, {'name': 'ETRS89 NTM 29 NN2000'}),
#              (5970, {'name': 'ETRS89 NTM 30 NN2000'}),
#              (5941, {'name': "NN2000 ('',)"}),
#              (5776, {'name': "NN54 ('',)"}),
#              (9672, {'name': 'CD Norway Depth'}),
#              (9883, {'name': 'CD Geografisk Norway Depth'}),
#              (20000, {'name': 'SVD2006 Svalbard'}),
#              (20001, {'name': 'SVD2006 Geografisk Svalbard'}),
#              (4273, {'name': 'NGO48 Geografisk 2D'}),
#              (27391, {'name': 'NGO48 Akse I 2D'}),
#              (27392, {'name': 'NGO48 Akse II 2D'}),
#              (27393, {'name': 'NGO48 Akse III 2D'}),
#              (27394, {'name': 'NGO48 Akse IV 2D'}),
#              (27395, {'name': 'NGO48 Akse V 2D'}),
#              (27396, {'name': 'NGO48 Akse VI 2D'}),
#              (27397, {'name': 'NGO48 Akse VII 2D'}),
#              (27398, {'name': 'NGO48 Akse VIII 2D'}),
#              (9000, {'name': 'ITRF2014 Geografisk 2D'}),
#              (7912, {'name': 'ITRF2014 Geografisk 3D'}),
#              (7789, {'name': 'ITRF2014 Geosentrisk'}),
#              (9990, {'name': 'ITRF2020 Geografisk 2D'}),
#              (9989, {'name': 'ITRF2020 Geografisk 3D'}),
#              (9988, {'name': 'ITRF2020 Geosentrisk'}),
#              (4230,
#               {'name': 'ED50 Geografisk 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23031,
#               {'name': 'ED50 UTM 31 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23032,
#               {'name': 'ED50 UTM 32 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23033,
#               {'name': 'ED50 UTM 33 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23034,
#               {'name': 'ED50 UTM 34 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23035,
#               {'name': 'ED50 UTM 35 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (23036,
#               {'name': 'ED50 UTM 36 2D',
#                'info': '(Gjelder foreløpig for sjø)'}),
#              (4326, {'name': 'WGS84 Geografisk 2D'})])

# %%
# Import Position und Unit class
from midgard.data.position import Position
from midgard.math.unit import Unit

# Define ITRF2014 position as Position object
pos_itrf2014 = Position([2169481.21111251,  627616.7736756 , 5944952.10084486], system="trs")

# Transform from ITRF2014 to EUREF89 based on geocentric coordinates
pos_euref89 = api.transform(
            x = pos_itrf2014.trs.x,  
            y = pos_itrf2014.trs.y,
            z = pos_itrf2014.trs.z,
            t = 2021.0, 
            from_epsg = 7789, 
            to_epsg = 4936,
)

print(f"pos_euref89: {pos_euref89}")
# Out:
# pos_euref89: [2169481.816360048, 627616.5116070558, 5944951.858863304]

# %%
# Transform from ITRF2014 to EUREF89 based on ellipsoidal coordinates
pos_euref89 = api.transform(
            x = pos_itrf2014.llh.lon * Unit.rad2deg,  
            y = pos_itrf2014.llh.lat * Unit.rad2deg,
            z = pos_itrf2014.llh.height,
            t = 2021.0, 
            from_epsg = 7912, 
            to_epsg = 4936,
)

print(f"pos_euref89: {pos_euref89}")
# Out:
# pos_euref89: [2169481.8163600485, 627616.511607056, 5944951.858863303]

# %% [markdown]
# The URL and/or proxy server can be chosen by initialization of the transformationApi object.

# %%
# Get instance of TransformationApi class by defining URL
api = transformation_api.TransformationApi(url="https://wstest.geonorge.no/transformering/v1")

# Get instance of TransformationApi class by defining proxy server
api = transformation_api.TransformationApi(proxy=None)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/requests/models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/miniconda3/envs/operax/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/miniconda3/envs/operax/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/miniconda3/envs/operax/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:123, in TransformationApi._error_message(url, response)
#     122 try:
# --> 123     response.json()
#     124 except JSONDecodeError:
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/requests/models.py:978, in Response.json(self, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Get instance of TransformationApi class by defining URL
# ----> 2 api = transformation_api.TransformationApi(url="https://wstest.geonorge.no/transformering/v1")
#       4 # Get instance of TransformationApi class by defining proxy server
#       5 api = transformation_api.TransformationApi(proxy=None)
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:55, in TransformationApi.__init__(self, url, proxy)
#      53 self.url = url.replace("#/", "")
#      54 self.proxy = proxy
# ---> 55 self.epsg = self._get_available_epsg()
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:160, in TransformationApi._get_available_epsg(self)
#     154 def _get_available_epsg(self) -> List[int]:
#     155     """Get available transformation API EPSG codes
#     156
#     157     Returns:
#     158         List with available EPSG codes
#     159     """
# --> 160     return list(self.projections.keys())
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:79, in TransformationApi.projections(self)
#      76 projections = OrderedDict()
#      77 url = f"{self.url}/projeksjoner"
# ---> 79 for proj in self._get_url(url).json():
#      80     projections[proj["epsg"]] = dict(name = proj["name"], info = proj["info"]) if "info" in proj else dict(name = proj["name"])
#      82 return projections
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:181, in TransformationApi._get_url(self, url)
#     178     raise ConnectionError(f"Failure by URL {url} call via proxy server {self.proxy}.\nError message: {err}")
#     180 except requests.exceptions.RequestException: # all requests exceptions inherit from RequestException
# --> 181     self._error_message(url, response)
#     183 return response
#
# File /opt/miniconda3/envs/operax/lib/python3.12/site-packages/midgard/api/transformation_api.py:125, in TransformationApi._error_message(url, response)
#     123     response.json()
#     124 except JSONDecodeError:
# --> 125     raise ConnectionError(f"Failure by URL {url} call\nStatus {response.status_code}: {response.text}")
#     126 #- Workaround due to official transformation API does not provide error messages as JSON files
#     127
#     128 #TODO: Use status code instead of text to check failure.
#     129 json = response.json()
#
# ConnectionError: Failure by URL https://wstest.geonorge.no/transformering/v1/projeksjoner call
# Status 403: <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
